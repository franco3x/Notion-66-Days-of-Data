# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("notion_data.csv")
df.head()
# Out:
#       Type                                               Name  \
# 0    Video  How To Become Expertise in Exploratory Data An...
# 1      NaN  101 Best Places to Learn to Code For Free | Le...
# 2    Video  Data Science Project from Scratch - Part 4 (Ex...
# 3  Article  I doubled my salary by switching to Tech! | by...
# 4    Video  How I Would Learn Data Science in 2022 (If I H...
#
#   Language/Software                     Packages  \
# 0            Python  matplotlib, pandas, seaborn
# 1               NaN                          NaN
# 2            Python  matplotlib, pandas, seaborn
# 3               NaN                          NaN
# 4               NaN                          NaN
#
#                                                 Tags        Author  \
# 0   #66DaysofData, Exploratory Data Analysis, Round1    Krish Naik
# 1                                                NaN           NaN
# 2  #66DaysofData, DS Projects, Exploratory Data A...       Ken Jee
# 3                      #66DaysofData, Career, Round1  Lanise Allen
# 4       #66DaysofData, Learning and Roadmaps, Round1       Ken Jee
#
#                     Created    Status   Score/5  \
# 0  January 1, 2022 11:32 PM  Finished    ⭐️⭐️⭐️
# 1  January 1, 2022 10:52 PM       NaN       NaN
# 2   January 1, 2022 9:28 PM  Finished  ⭐️⭐️⭐️⭐️
# 3   January 1, 2022 5:32 PM  Finished       NaN
# 4   January 1, 2022 5:04 PM  Finished       NaN
#
#                                                  URL   Source  Minutes  \
# 0        https://www.youtube.com/watch?v=dP170R-wO-8  YouTube     10.1
# 1    https://learntocodewith.me/posts/code-for-free/      NaN      NaN
# 2  https://www.youtube.com/watch?v=QWgg4w1SpJ8&t=28s  YouTube     68.6
# 3  https://laniseallen.medium.com/i-doubled-my-sa...   Medium      3.0
# 4        https://www.youtube.com/watch?v=xpIFS6jZbe8  YouTube     12.2
#
#        Finish Date       Start Date     Hours Notes? Linked Up?  \
# 0  January 1, 2022  January 1, 2022  0.168333     No         No
# 1              NaN              NaN  0.000000     No         No
# 2  January 1, 2022  January 1, 2022  1.143333     No         No
# 3  January 1, 2022  January 1, 2022  0.050000     No         No
# 4  January 1, 2022  January 1, 2022  0.203333     No         No
#
#   Related to Coding Course Notes (Property)  Property
# 0                                       NaN       NaN
# 1                                       NaN       NaN
# 2                                       NaN       NaN
# 3                                       NaN       NaN
# 4                                       NaN       NaN

# %%
df.columns
# Out:
# Index(['Type', 'Name', 'Language/Software', 'Packages', 'Tags', 'Author',
#        'Created', 'Status', 'Score/5', 'URL', 'Source', 'Minutes',
#        'Finish Date', 'Start Date', 'Hours', 'Notes?', 'Linked Up?',
#        'Related to Coding Course Notes (Property)', 'Property'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Type                                          object
# Name                                          object
# Language/Software                             object
# Packages                                      object
# Tags                                          object
# Author                                        object
# Created                                       object
# Status                                        object
# Score/5                                       object
# URL                                           object
# Source                                        object
# Minutes                                      float64
# Finish Date                                   object
# Start Date                                    object
# Hours                                        float64
# Notes?                                        object
# Linked Up?                                    object
# Related to Coding Course Notes (Property)     object
# Property                                     float64
# dtype: object

# %%
df = df.drop("Property", axis=1)

# %%
dfc = df.columns

# %%
df.drop(['Related to Coding Course Notes (Property)', 'Linked Up?'], axis=1)
# Out:
#         Type                                               Name  \
# 0      Video  How To Become Expertise in Exploratory Data An...
# 1        NaN  101 Best Places to Learn to Code For Free | Le...
# 2      Video  Data Science Project from Scratch - Part 4 (Ex...
# 3    Article  I doubled my salary by switching to Tech! | by...
# 4      Video  How I Would Learn Data Science in 2022 (If I H...
# ..       ...                                                ...
# 109    Video  Data Science Project from Scratch - Part 2 (Da...
# 110    Video  (50) The Second Brain - A Life-Changing Produc...
# 111    Video  Data Science Project from Scratch - Part 1 (Pr...
# 112     Book  Data Newbie to Guru: The Visual Guide to Learn...
# 113  Podcast                   Build Your Brand in Data Science
#
#     Language/Software                     Packages  \
# 0              Python  matplotlib, pandas, seaborn
# 1                 NaN                          NaN
# 2              Python  matplotlib, pandas, seaborn
# 3                 NaN                          NaN
# 4                 NaN                          NaN
# ..                ...                          ...
# 109               NaN                          NaN
# 110               NaN                          NaN
# 111               NaN                          NaN
# 112               NaN                          NaN
# 113               NaN                          NaN
#
#                                                   Tags             Author  \
# 0     #66DaysofData, Exploratory Data Analysis, Round1         Krish Naik
# 1                                                  NaN                NaN
# 2    #66DaysofData, DS Projects, Exploratory Data A...            Ken Jee
# 3                        #66DaysofData, Career, Round1       Lanise Allen
# 4         #66DaysofData, Learning and Roadmaps, Round1            Ken Jee
# ..                                                 ...                ...
# 109                          DS Projects, Data Science            Ken Jee
# 110                                       Productivity         Ali Abdaal
# 111                          DS Projects, Data Science            Ken Jee
# 112                                  Data Science, SQL  Dr. Chantel Perry
# 113                                       Data Science                NaN
#
#                        Created    Status     Score/5  \
# 0     January 1, 2022 11:32 PM  Finished      ⭐️⭐️⭐️
# 1     January 1, 2022 10:52 PM       NaN         NaN
# 2      January 1, 2022 9:28 PM  Finished    ⭐️⭐️⭐️⭐️
# 3      January 1, 2022 5:32 PM  Finished         NaN
# 4      January 1, 2022 5:04 PM  Finished         NaN
# ..                         ...       ...         ...
# 109  December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 110  December 21, 2021 5:58 PM  Finished         NaN
# 111  December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 112  December 21, 2021 5:58 PM   Started         NaN
# 113  December 21, 2021 5:58 PM       NaN         NaN
#
#                                                    URL   Source  Minutes  \
# 0          https://www.youtube.com/watch?v=dP170R-wO-8  YouTube    10.10
# 1      https://learntocodewith.me/posts/code-for-free/      NaN      NaN
# 2    https://www.youtube.com/watch?v=QWgg4w1SpJ8&t=28s  YouTube    68.60
# 3    https://laniseallen.medium.com/i-doubled-my-sa...   Medium     3.00
# 4          https://www.youtube.com/watch?v=xpIFS6jZbe8  YouTube    12.20
# ..                                                 ...      ...      ...
# 109        https://www.youtube.com/watch?v=GmW4F6MHqqs      NaN    28.00
# 110        https://www.youtube.com/watch?v=OP3dA2GcAh8      NaN    15.51
# 111        https://www.youtube.com/watch?v=MpF9HENQjDo      NaN     7.50
# 112                                                NaN      NaN      NaN
# 113  https://podcasts.apple.com/us/podcast/50-ken-j...      NaN    56.00
#
#             Finish Date          Start Date     Hours Notes?
# 0       January 1, 2022     January 1, 2022  0.168333     No
# 1                   NaN                 NaN  0.000000     No
# 2       January 1, 2022     January 1, 2022  1.143333     No
# 3       January 1, 2022     January 1, 2022  0.050000     No
# 4       January 1, 2022     January 1, 2022  0.203333     No
# ..                  ...                 ...       ...    ...
# 109  September 23, 2020  September 23, 2020  0.466667     No
# 110  September 25, 2020  September 25, 2020  0.258500     No
# 111  September 23, 2020  September 23, 2020  0.125000     No
# 112                 NaN       July 31, 2020  0.000000     No
# 113                 NaN  September 23, 2020  0.933333     No
#
# [114 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Type', 'Name', 'Language/Software', 'Packages', 'Tags', 'Author',
#        'Created', 'Status', 'Score/5', 'URL', 'Source', 'Minutes',
#        'Finish Date', 'Start Date', 'Hours', 'Notes?', 'Linked Up?',
#        'Related to Coding Course Notes (Property)'],
#       dtype='object')

# %%
df.describe()
# Out:
#           Minutes       Hours
# count   40.000000  114.000000
# mean    67.680500    0.395792
# std    131.640925    1.397761
# min      1.000000    0.000000
# 25%     10.272500    0.000000
# 50%     29.000000    0.000000
# 75%     57.475000    0.174292
# max    739.900000   12.331667

# %%
df.Type.describe()
# Out:
# count        79
# unique        6
# top       Video
# freq         31
# Name: Type, dtype: object

# %%
df.Type.hist()
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x='Type', data=df, kind='count')

# %%
df.Type.value_counts()
# Out:
# Video      31
# Article    25
# Course     13
# Podcast     5
# Tweet       4
# Book        1
# Name: Type, dtype: int64

# %%
df.Type.value_counts(normalize=True)
# Out:
# Video      0.392405
# Article    0.316456
# Course     0.164557
# Podcast    0.063291
# Tweet      0.050633
# Book       0.012658
# Name: Type, dtype: float64

# %%
dfc
# Out:
# Index(['Type', 'Name', 'Language/Software', 'Packages', 'Tags', 'Author',
#        'Created', 'Status', 'Score/5', 'URL', 'Source', 'Minutes',
#        'Finish Date', 'Start Date', 'Hours', 'Notes?', 'Linked Up?',
#        'Related to Coding Course Notes (Property)'],
#       dtype='object')

# %%
df.Status.value_counts(normalize=True)
# Out:
# Finished       0.661017
# Started        0.186441
# Not Started    0.152542
# Name: Status, dtype: float64

# %%
df[df["Status"] == "Finished"]
# Out:
#         Type                                               Name  \
# 0      Video  How To Become Expertise in Exploratory Data An...
# 2      Video  Data Science Project from Scratch - Part 4 (Ex...
# 3    Article  I doubled my salary by switching to Tech! | by...
# 4      Video  How I Would Learn Data Science in 2022 (If I H...
# 5    Article  A 22-week curriculum to learn Data Analytics i...
# 6      Video  5 Beginner Data Science Projects to start toda...
# 7      Video  Exploratory Data Analysis (comment your best i...
# 8      Video  Python Functions | Python Tutorial for Absolut...
# 10   Article  Use Python To Scrape & Visualize Likes On Your...
# 16     Video  Pivot Tables in Excel | Excel Tutorials for Be...
# 18     Video  Overview, Review and Study Tips - Google Data ...
# 19     Video  How to learn data science in 2021 (the minimiz...
# 20     Video  The Art of Learning Data Science (How to learn...
# 24     Video  Data Analyst Setup for Productivity (Python, R...
# 25     Video  Exploratory Data Analysis (comment your best i...
# 27   Podcast  ‎DataFramed: #69 Effective Data Storytelling: ...
# 29    Course                           Joining Data with pandas
# 37   Article  How to pass the Facebook Data Science intervie...
# 41   Article  www.r2d3.us/visual-intro-to-machine-learning-p...
# 43   Article  A Gentle Introduction to Exploratory Data Anal...
# 47     Video  Data Scientist: Reality vs Expectations 2 ($11...
# 55     Video  Mastering Python - Everything You Need To Know...
# 59    Course      01 - Introduction - Data Analysis with Python
# 61     Video  His Startup Will Land You a Data Science Job |...
# 66   Article          A visual introduction to machine learning
# 67     Video       Data Science Projects for Beginners (Kaggle)
# 69     Tweet                                               Fear
# 70    Course            04 - How to use Jupyter Notebooks Intro
# 71    Course  03 - Data Analysis Example B - Data Analysis w...
# 73     Video  Building A Second Brain - Deep Dive with Tiago...
# 74     Video  The 7 Steps of Machine Learning (AI Adventures...
# 76     Video  9 Passive Income Ideas - How I Make $27k per W...
# 77     Video  10 tips for learning PYTHON fast! Master Pytho...
# 91   Podcast  ‎The GaryVee Audio Experience: Why NFT project...
# 95    Course  02 - Data Analysis Example A - Data Analysis w...
# 102    Video  Buying vs Leasing a Car 101: How to pick the B...
# 109    Video  Data Science Project from Scratch - Part 2 (Da...
# 110    Video  (50) The Second Brain - A Life-Changing Produc...
# 111    Video  Data Science Project from Scratch - Part 1 (Pr...
#
#     Language/Software                     Packages  \
# 0              Python  matplotlib, pandas, seaborn
# 2              Python  matplotlib, pandas, seaborn
# 3                 NaN                          NaN
# 4                 NaN                          NaN
# 5                 NaN                          NaN
# 6              Python                          NaN
# 7              Python                       pandas
# 8              Python                          NaN
# 10             Python                     Selenium
# 16              Excel                          NaN
# 18                NaN                          NaN
# 19                NaN                          NaN
# 20                NaN                          NaN
# 24             Python                          NaN
# 25             Python                       pandas
# 27                NaN                          NaN
# 29             Python                       pandas
# 37                NaN                          NaN
# 41                NaN                          NaN
# 43                NaN                          NaN
# 47                NaN                          NaN
# 55                NaN                          NaN
# 59                NaN                          NaN
# 61                NaN                          NaN
# 66                NaN                          NaN
# 67                NaN                          NaN
# 69                NaN                          NaN
# 70                NaN                          NaN
# 71                NaN                          NaN
# 73                NaN                          NaN
# 74                NaN                          NaN
# 76                NaN                          NaN
# 77                NaN                          NaN
# 91                NaN                          NaN
# 95                NaN                          NaN
# 102               NaN                          NaN
# 109               NaN                          NaN
# 110               NaN                          NaN
# 111               NaN                          NaN
#
#                                                   Tags                 Author  \
# 0     #66DaysofData, Exploratory Data Analysis, Round1             Krish Naik
# 2    #66DaysofData, DS Projects, Exploratory Data A...                Ken Jee
# 3                        #66DaysofData, Career, Round1           Lanise Allen
# 4         #66DaysofData, Learning and Roadmaps, Round1                Ken Jee
# 5         #66DaysofData, Learning and Roadmaps, Round1         Aakriti Sharma
# 6                   #66DaysofData, DS Projects, Round1            Tina Hauang
# 7    #66DaysofData, Exploratory Data Analysis, Pyth...     Shashank Kalanithi
# 8             #66DaysofData, Functions, Python, Round1  Programming with Mosh
# 10   #66DaysofData, Data Analysis, Data Science, Ex...  Stanislav Lukashevich
# 16          #66DaysofData, Excel, Pivot Tables, Round1       Alex the Analyst
# 18                 #66DaysofData, Data Science, Round1            Tina Hauang
# 19                 #66DaysofData, Data Science, Round1            Tina Hauang
# 20                 #66DaysofData, Data Science, Round1         Data Professor
# 24                                        Data Science     Shashank Kalanithi
# 25   #66DaysofData, Exploratory Data Analysis, Pyth...     Shashank Kalanithi
# 27            #66DaysofData, Data Storytelling, Round1                    NaN
# 29               #66DaysofData, Pandas, Python, Round1                    NaN
# 37                            Data Science, Interviews                    NaN
# 41                      Data Science, Machine Learning                    NaN
# 43   Data Science, Exploratory Data Analysis, Machi...          Daniel Bourke
# 47                            Data Science, Interviews                    NaN
# 55                                              Python          Tech with Tim
# 59                 Data Analysis, Data Science, Python                    NaN
# 61                            Data Science, Interviews                Ken Jee
# 66                      Data Science, Machine Learning                    NaN
# 67                                        Data Science                Ken Jee
# 69                                                 NaN                    NaN
# 70                 Data Analysis, Data Science, Python                    NaN
# 71                 Data Analysis, Data Science, Python                    NaN
# 73                                        Productivity             Ali Abdaal
# 74                      Data Science, Machine Learning  Google Cloud Platform
# 76                                                 NaN             Ali Abdaal
# 77                                              Python      Python Programmer
# 91                                                 NaN                    NaN
# 95                 Data Analysis, Data Science, Python                    NaN
# 102                                                NaN                    NaN
# 109                          DS Projects, Data Science                Ken Jee
# 110                                       Productivity             Ali Abdaal
# 111                          DS Projects, Data Science                Ken Jee
#
#                         Created    Status     Score/5  \
# 0      January 1, 2022 11:32 PM  Finished      ⭐️⭐️⭐️
# 2       January 1, 2022 9:28 PM  Finished    ⭐️⭐️⭐️⭐️
# 3       January 1, 2022 5:32 PM  Finished         NaN
# 4       January 1, 2022 5:04 PM  Finished         NaN
# 5      January 1, 2022 10:01 AM  Finished         NaN
# 6     December 31, 2021 8:52 PM  Finished         NaN
# 7     December 31, 2021 7:17 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 8    December 31, 2021 10:28 AM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 10    December 31, 2021 9:13 AM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 16    December 29, 2021 4:48 PM  Finished         NaN
# 18    December 29, 2021 3:51 PM  Finished         NaN
# 19    December 29, 2021 3:27 PM  Finished         NaN
# 20    December 29, 2021 1:00 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 24    December 28, 2021 4:19 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 25    December 28, 2021 4:05 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 27    December 28, 2021 3:13 PM  Finished         NaN
# 29    December 22, 2021 8:55 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 37    December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 41    December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 43    December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 47    December 21, 2021 5:58 PM  Finished    ⭐️⭐️⭐️⭐️
# 55    December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 59    December 21, 2021 5:58 PM  Finished         NaN
# 61    December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 66    December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 67    December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 69    December 21, 2021 5:58 PM  Finished         NaN
# 70    December 21, 2021 5:58 PM  Finished         NaN
# 71    December 21, 2021 5:58 PM  Finished         NaN
# 73    December 21, 2021 5:58 PM  Finished         NaN
# 74    December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 76    December 21, 2021 5:58 PM  Finished         NaN
# 77    December 21, 2021 5:58 PM  Finished         NaN
# 91    December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 95    December 21, 2021 5:58 PM  Finished         NaN
# 102   December 21, 2021 5:58 PM  Finished         NaN
# 109   December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
# 110   December 21, 2021 5:58 PM  Finished         NaN
# 111   December 21, 2021 5:58 PM  Finished  ⭐️⭐️⭐️⭐️⭐️
#
#                                                    URL    Source  Minutes  \
# 0          https://www.youtube.com/watch?v=dP170R-wO-8   YouTube    10.10
# 2    https://www.youtube.com/watch?v=QWgg4w1SpJ8&t=28s   YouTube    68.60
# 3    https://laniseallen.medium.com/i-doubled-my-sa...    Medium     3.00
# 4          https://www.youtube.com/watch?v=xpIFS6jZbe8   YouTube    12.20
# 5                  https://link.medium.com/zFIJGDfVsmb    Medium     5.00
# 6          https://www.youtube.com/watch?v=PwE-xuw5sNU   YouTube    13.20
# 7    https://www.youtube.com/watch?v=E-q24gS8cqg&t=...   YouTube    58.90
# 8          https://www.youtube.com/watch?v=u-OmVr_fT4s   YouTube    30.50
# 10   https://www.linkedin.com/pulse/use-python-scra...  LinkedIn     5.00
# 16   https://www.youtube.com/watch?v=lH7HfwUFnYA&li...   YouTube    17.50
# 18         https://www.youtube.com/watch?v=cvTpocrPNlo   YouTube    33.30
# 19    https://www.youtube.com/watch?v=Axu4tJl8gbM&t=0s   YouTube    12.25
# 20   https://www.youtube.com/watch?v=oR670Txwh88&t=...   YouTube    32.90
# 24         https://www.youtube.com/watch?v=LwazHUkU5IQ   YouTube    34.60
# 25   https://www.youtube.com/watch?v=E-q24gS8cqg&t=...   YouTube    58.90
# 27   https://podcasts.apple.com/us/podcast/datafram...       NaN    52.00
# 29                                                 NaN  DataCamp   240.00
# 37   https://towardsdatascience.com/how-to-pass-the...    Medium      NaN
# 41   http://www.r2d3.us/visual-intro-to-machine-lea...       NaN      NaN
# 43   https://towardsdatascience.com/a-gentle-introd...       NaN    30.00
# 47         https://www.youtube.com/watch?v=0X2H-ZD_Chw       NaN      NaN
# 55         https://www.youtube.com/watch?v=p15xzjzR9j0       NaN    16.00
# 59   https://www.youtube.com/watch?time_continue=1&...       NaN    10.00
# 61         https://www.youtube.com/watch?v=7VcdvSyoxnc       NaN    61.75
# 66   http://www.r2d3.us/visual-intro-to-machine-lea...       NaN      NaN
# 67         https://www.youtube.com/watch?v=8igH8qZafpo   YouTube     7.50
# 69   https://twitter.com/tirzahmj/status/1220580181...       NaN     1.00
# 70   https://www.youtube.com/watch?v=h8caJq2Bb9w&fe...       NaN     8.75
# 71   https://www.youtube.com/watch?v=0kJz0q0pvgQ&fe...       NaN    10.33
# 73         https://www.youtube.com/watch?v=--x10rQ4FvI       NaN   106.30
# 74   https://www.youtube.com/watch?v=nKW8Ndu7Mjw&t=48s   YouTube      NaN
# 76         https://www.youtube.com/watch?v=M5y69v1RbU0   YouTube    30.00
# 77         https://www.youtube.com/watch?v=xsEXpzsLsc0       NaN    10.50
# 91   https://podcasts.apple.com/us/podcast/the-gary...       NaN    57.00
# 95   https://www.youtube.com/watch?time_continue=7&...       NaN     9.33
# 102        https://www.youtube.com/watch?v=CR3zm9MYxhE   YouTube    11.50
# 109        https://www.youtube.com/watch?v=GmW4F6MHqqs       NaN    28.00
# 110        https://www.youtube.com/watch?v=OP3dA2GcAh8       NaN    15.51
# 111        https://www.youtube.com/watch?v=MpF9HENQjDo       NaN     7.50
#
#             Finish Date          Start Date     Hours Notes? Linked Up?  \
# 0       January 1, 2022     January 1, 2022  0.168333     No         No
# 2       January 1, 2022     January 1, 2022  1.143333     No         No
# 3       January 1, 2022     January 1, 2022  0.050000     No         No
# 4       January 1, 2022     January 1, 2022  0.203333     No         No
# 5       January 1, 2022     January 1, 2022  0.083333     No         No
# 6     December 31, 2021   December 31, 2021  0.220000     No         No
# 7     December 31, 2021   December 31, 2021  0.981667     No         No
# 8     December 31, 2021   December 31, 2021  0.508333     No         No
# 10    December 31, 2021   December 31, 2021  0.083333     No         No
# 16    December 29, 2021   December 29, 2021  0.291667     No         No
# 18    December 29, 2021   December 29, 2021  0.555000     No         No
# 19    December 29, 2021   December 29, 2021  0.204167     No         No
# 20    December 29, 2021   December 29, 2021  0.548333    Yes         No
# 24    December 20, 2021   December 20, 2021  0.576667     No         No
# 25    December 20, 2021   December 20, 2021  0.981667     No         No
# 27                  NaN                 NaN  0.866667    Yes         No
# 29    December 28, 2021   December 17, 2021  4.000000    Yes         No
# 37                  NaN                 NaN  0.000000     No         No
# 41                  NaN                 NaN  0.000000     No         No
# 43   September 11, 2020  September 11, 2020  0.500000     No         No
# 47                  NaN                 NaN  0.000000     No         No
# 55   September 16, 2020  September 16, 2020  0.266667     No         No
# 59       August 6, 2020      August 6, 2020  0.166667     No         No
# 61   September 23, 2020  September 23, 2020  1.029167     No         No
# 66                  NaN                 NaN  0.000000     No         No
# 67   September 16, 2020  September 16, 2020  0.125000    Yes         No
# 69       August 3, 2020      August 3, 2020  0.016667     No         No
# 70       August 8, 2020      August 8, 2020  0.145833     No         No
# 71       August 6, 2020      August 6, 2020  0.172167     No         No
# 73   September 26, 2020  September 26, 2020  1.771667     No         No
# 74                  NaN                 NaN  0.000000     No         No
# 76       April 17, 2021      April 17, 2021  0.500000     No         No
# 77   September 16, 2020  September 16, 2020  0.175000    Yes         No
# 91      August 20, 2021     August 20, 2021  0.950000     No         No
# 95       August 6, 2020      August 6, 2020  0.155500     No         No
# 102      April 17, 2021      April 17, 2021  0.191667     No         No
# 109  September 23, 2020  September 23, 2020  0.466667     No         No
# 110  September 25, 2020  September 25, 2020  0.258500     No         No
# 111  September 23, 2020  September 23, 2020  0.125000     No         No
#
#     Related to Coding Course Notes (Property)
# 0                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 10                                        NaN
# 16                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 24                                        NaN
# 25                                        NaN
# 27                                        NaN
# 29                                        NaN
# 37                                        NaN
# 41                                        NaN
# 43                                        NaN
# 47                                        NaN
# 55                                        NaN
# 59                                        NaN
# 61                                        NaN
# 66                                        NaN
# 67                                        NaN
# 69                                        NaN
# 70                                        NaN
# 71                                        NaN
# 73                                        NaN
# 74                                        NaN
# 76                                        NaN
# 77                                        NaN
# 91                                        NaN
# 95                                        NaN
# 102                                       NaN
# 109                                       NaN
# 110                                       NaN
# 111                                       NaN

# %%
df.Status.isna().sum()
# Out:
# 55
